# %% [markdown]
# # Python Dictionaries Implementation
#
# *Implement dictionaries with different data structures (red-black trees and hash tables) from scratch and analyze their performance in different scenarios*
#
# ### Exam Notes
#
# About the presentation:
#
# - It should be 15-20 minutes, with additional 5 minutes of questions (either during the talk or afterwards)
#
# - Your presentation should focus on the algorithmic part of whatever you chose
#
# - Questions can also be about the related parts in the course (if your algorithm uses, e.g., a binary search tree, we might ask you about properties and applications of binary search trees)

# %% [markdown]
# ## 1.0 First Implementation: Hash Tables
#
# Summary: we have a key, we send it through an hash function that it is going to hashing it really fast and then map the output into a memory address where we will store our data.
#
# ### Time Complexity:
#  - Insert: O(1)
#  - Lookup: O(1)
#  - Delete: O(1)
#  - Search: O(1)
#
#
# ### How to Implement Hash Tables
# 1. Use a fast Hash Function. Eg. SHA-256 takes a very long time to compute the hash and it is overly complex.
# 2. Implement Linked-List to solve Hash Collisions

# %% [markdown]
# ## 2.0 Second Implementation: Red Black Trees
#
# [Red Black Trees Explanation](https://medium.com/basecs/painting-nodes-black-with-red-black-trees-60eacb2be9a5)
#
# > A red-black tree is a type of self-balancing binary search tree, very similar to other self-balancing trees, such as AVL trees. However, a red-black tree is a structure that has to adhere to a very strict set of rules in order to make sure that it stays balanced; the rules of a red-black tree are exactly what enables it to maintain a guaranteed logarithmic time complexity.
#
# 1. Every single node in the tree must be either red or black.
# 2. The root node of the tree must always be black.
# 3. Two red nodes can never appear consecutively, one after another; a red node must always be preceded by a black node (it must have a black parent node), and a red node must always have black children nodes.
# 4. Every branch path — the path from a root node to an empty (null) leaf node — must pass through the exact same number of black nodes. A branch path from the root to an empty leaf node is also known as an unsuccessful search path, since it represents the path we would take if we were to search for a node that didn’t exist within the tree.
#
# [*Why Red Black Trees?*](https://stackoverflow.com/questions/13852870/red-black-tree-over-avl-tree)
#
# > Both red-black trees and AVL trees are the most commonly used balanced binary search trees and they support insertion, deletion and look-up in guaranteed O(logN) time. However, there are following points of comparison between the two:
#
# > AVL trees are more rigidly balanced and hence provide faster look-ups. Thus for a look-up intensive task use an AVL tree.
# For an insert intensive tasks, use a Red-Black tree.
# AVL trees store the balance factor at each node. This takes O(N) extra space. However, if we know that the keys that will be inserted in the tree will always be greater than zero, we can use the sign bit of the keys to store the colour information of a red-black tree. Thus, in such cases red-black tree takes no extra space.
# What are the application of Red black tree?
# Red-black trees are more general purpose. They do relatively well on add, remove, and look-up but AVL trees have faster look-ups at the cost of slower add/remove.
#
# ### Notes:
#  1. it’s easiest to start off by always inserting a red node, and then recoloring and rotation as necessary, afterwards
#
#
#
# 2. https://stackoverflow.com/questions/17279805/how-do-i-implement-a-hashtable-using-a-binary-search-tree
#
# > No, we do not need to calculate an index or use a hashing function. If we store the key,value pairs in the nodes of the bst, then its just a matter of traversing the tree by comparing the keys. This also gives you the added advantage of no collisions since the keys are unique.
#
# > You could use a hashing function and hash the key and then traverse the tree based on that value but this can lead to collisions if you are not careful with the hash function and then you would have to maintain some sort of chaining.
#
# > Whether to use the key or the hashed value of the key depends on the size of the key. If the key size is large, it makes sense to hash it to a smaller size for faster comparison.

# %%
from HashTable import NaiveHashTable, DefaultHashTable, MD5HashTable, SHA256HashTable, JenkinsHashTable
from MapRBTree import MapRBTree

# %% [markdown]
# # Analyze Performance

# %%
import pandas as pd
import numpy as np
import statistics

# %%
def insert_keys(hashtable, n=10000):
    for i in range(n):
        hashtable.add(str(i), i)
        
def get_values(hashtable, n=10000):
    for i in range(n):
        hashtable.get(str(i))
        
def delete_values(hashtable, n=10000):
    for i in range(n):
        hashtable.delete(str(i), testing=True)

# %%
def get_hashtable(kind, size):
    hashtables = {
        'Naive': NaiveHashTable(size),
        'Default': DefaultHashTable(size),
        'MD5': MD5HashTable(size),
        'SHA256': SHA256HashTable(size),
        'Jenkins': JenkinsHashTable(size)
    }
        
    return hashtables[kind]

# %% [markdown]
# ## Hash Table Size Change Analysis

# %%
def get_results(kind, size_array):
    res_insert = []
    res_get = []
    res_del = []
    for size in size_array:
        print(kind, size)
        hashtable = get_hashtable(kind, size)
        insert = %timeit -o -n 100 insert_keys(hashtable, n=10000)
        get = %timeit -o -n 100 get_values(hashtable, n=1000)
        delete = %timeit -o -n 100 delete_values(hashtable, n=1000)
        res_insert.append(insert)
        res_get.append(get)
        res_del.append(delete)
    return res_insert, res_get, res_del

# %%
hashtable_kind = ['Naive', 'Default', 'MD5', 'SHA256', 'Jenkins']
size_array = [10, 50, 250, 500, 1000, 2000, 5000, 15000, 25000, 100000]


results = []
for kind in hashtable_kind:
    results.append((kind, get_results(kind, size_array)))
# Out:
# Naive 10
# 26.4 ms ± 1.3 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.55 ms ± 372 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.48 ms ± 478 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 50
# 26.2 ms ± 1.11 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.51 ms ± 87.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.51 ms ± 76.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 250
# 25.3 ms ± 617 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.3 ms ± 65.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.34 ms ± 78.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 500
# 27.9 ms ± 1.3 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.07 ms ± 571 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.46 ms ± 190 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 1000
# 26.6 ms ± 641 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.48 ms ± 59 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.5 ms ± 50.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 2000
# 26.3 ms ± 610 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.48 ms ± 495 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.85 ms ± 202 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 5000
# 26.8 ms ± 853 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.5 ms ± 148 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.52 ms ± 211 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 15000
# 28.3 ms ± 2.42 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.58 ms ± 96.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.51 ms ± 83.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 25000
# 26.8 ms ± 741 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.46 ms ± 113 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.5 ms ± 118 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 100000
# 26.7 ms ± 900 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.49 ms ± 78.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.72 ms ± 342 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 10
# 16.9 ms ± 1.89 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.09 ms ± 452 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.51 ms ± 96.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 50
# 13.1 ms ± 177 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.67 ms ± 116 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.61 ms ± 26.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 250
# 13.8 ms ± 957 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2 ms ± 94.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.84 ms ± 56.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 500
# 15.8 ms ± 1.2 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.84 ms ± 110 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.04 ms ± 182 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 1000
# 14.8 ms ± 797 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.82 ms ± 38.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.79 ms ± 26.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 2000
# 13.5 ms ± 751 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.8 ms ± 64.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.33 ms ± 400 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 5000
# 15.5 ms ± 648 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.76 ms ± 41.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.76 ms ± 21.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 15000
# 14.6 ms ± 1.06 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.73 ms ± 66.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.74 ms ± 40.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 25000
# 14.8 ms ± 1.84 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.96 ms ± 123 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.78 ms ± 40 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 100000
# 15 ms ± 1.31 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.92 ms ± 155 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.96 ms ± 108 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 10
# 30.6 ms ± 693 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.52 ms ± 1.32 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.96 ms ± 463 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 50
# 30.9 ms ± 767 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.64 ms ± 92.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.61 ms ± 55.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 250
# 34.7 ms ± 2.84 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.82 ms ± 60.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.02 ms ± 254 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 500
# 32.6 ms ± 751 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.21 ms ± 310 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.73 ms ± 885 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 1000
# 35.1 ms ± 2.5 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.76 ms ± 74.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.74 ms ± 52.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 2000
# 31.7 ms ± 939 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.72 ms ± 108 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.87 ms ± 148 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 5000
# 30.1 ms ± 2.17 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.26 ms ± 36.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.27 ms ± 18.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 15000
# 29.3 ms ± 1.69 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.27 ms ± 55.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.19 ms ± 50.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 25000
# 29 ms ± 1.54 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.8 ms ± 388 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.33 ms ± 80.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 100000
# 29 ms ± 1.05 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.37 ms ± 93.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.23 ms ± 62.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 10
# 29.5 ms ± 439 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.99 ms ± 155 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.22 ms ± 181 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 50
# 30.3 ms ± 559 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.33 ms ± 52.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.44 ms ± 176 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 250
# 30.7 ms ± 996 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.83 ms ± 181 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.86 ms ± 198 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 500
# 31.2 ms ± 523 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.55 ms ± 81.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.62 ms ± 82.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 1000
# 31.5 ms ± 1.61 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.55 ms ± 87.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.72 ms ± 62 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 2000
# 30.4 ms ± 672 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.66 ms ± 207 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.58 ms ± 92.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 5000
# 31.7 ms ± 3.09 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.46 ms ± 89.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.58 ms ± 120 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 15000
# 32.5 ms ± 669 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.69 ms ± 115 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.58 ms ± 145 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 25000
# 30.6 ms ± 1.22 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.5 ms ± 97.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.6 ms ± 57.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 100000
# 31.4 ms ± 939 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.64 ms ± 74.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.5 ms ± 89.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 10
# 75 ms ± 1.98 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 12 ms ± 133 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 12.3 ms ± 99.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 50
# 75.1 ms ± 1.09 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.55 ms ± 114 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.45 ms ± 136 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 250
# 82 ms ± 8.44 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.19 ms ± 153 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.3 ms ± 83.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 500
# 79.2 ms ± 1.18 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.25 ms ± 87.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.14 ms ± 68.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 1000
# 80.6 ms ± 3.42 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.18 ms ± 107 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.24 ms ± 162 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 2000
# 79.4 ms ± 1.58 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.21 ms ± 83 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.5 ms ± 697 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 5000
# 77.6 ms ± 6.87 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.31 ms ± 2.42 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11 ms ± 525 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 15000
# 70.8 ms ± 4.15 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.85 ms ± 209 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.05 ms ± 113 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 25000
# 72 ms ± 4.04 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.21 ms ± 702 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.47 ms ± 601 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 100000
# 72.4 ms ± 4.39 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.66 ms ± 650 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.72 ms ± 583 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Format Results

# %%
#insert
insert_res= []
for i in [res[1][0] for res in results]: 
    insert_res.append([statistics.mean(time_res.timings) for time_res in i])
    
insert_df = pd.DataFrame(insert_res).T
insert_df.columns=[res[0] for res in results]
insert_df.index = size_array

# %%
insert_df
# Out:
#            Naive   Default       MD5    SHA256   Jenkins
# 10      0.026356  0.016924  0.030615  0.029499  0.074966
# 50      0.026208  0.013058  0.030930  0.030296  0.075141
# 250     0.025273  0.013769  0.034732  0.030739  0.081957
# 500     0.027910  0.015828  0.032642  0.031196  0.079185
# 1000    0.026583  0.014779  0.035087  0.031464  0.080593
# 2000    0.026311  0.013515  0.031676  0.030394  0.079405
# 5000    0.026781  0.015516  0.030097  0.031728  0.077606
# 15000   0.028311  0.014557  0.029311  0.032538  0.070780
# 25000   0.026850  0.014846  0.029001  0.030567  0.072017
# 100000  0.026656  0.015011  0.028992  0.031433  0.072377

# %%
#insert_df.to_csv('./Results/insert_size_change-3.csv')

# %%
#get
get_res = []
for i in [res[1][1] for res in results]: 
    get_res.append([statistics.mean(time_res.timings) for time_res in i])
    
get_df = pd.DataFrame(get_res).T
get_df.columns=[res[0] for res in results]
get_df.index = size_array

# %%
get_df
# Out:
#            Naive   Default       MD5    SHA256   Jenkins
# 10      0.007545  0.007092  0.009521  0.007988  0.012014
# 50      0.004506  0.002674  0.004641  0.004326  0.008551
# 250     0.004297  0.001997  0.003823  0.003827  0.008189
# 500     0.005069  0.001838  0.004213  0.003547  0.008249
# 1000    0.004484  0.001819  0.003765  0.003546  0.008178
# 2000    0.005481  0.001800  0.003723  0.003660  0.008209
# 5000    0.004500  0.001756  0.003259  0.003464  0.009308
# 15000   0.004578  0.001731  0.003275  0.003685  0.006853
# 25000   0.004461  0.001965  0.003799  0.003495  0.007209
# 100000  0.004490  0.001923  0.003369  0.003636  0.007657

# %%
#get_df.to_csv('./Results/get_size_change-3.csv')

# %%
#del
del_res = []
for i in [res[1][2] for res in results]: 
    del_res.append([statistics.mean(time_res.timings) for time_res in i])
    
del_df = pd.DataFrame(del_res).T
del_df.columns=[res[0] for res in results]
del_df.index = size_array

# %%
del_df
# Out:
#            Naive   Default       MD5    SHA256   Jenkins
# 10      0.007480  0.006507  0.008958  0.008220  0.012310
# 50      0.004512  0.002610  0.004609  0.004445  0.008455
# 250     0.004345  0.001835  0.004015  0.003861  0.008302
# 500     0.004458  0.002043  0.004735  0.003619  0.008144
# 1000    0.004497  0.001789  0.003744  0.003719  0.008240
# 2000    0.004852  0.002328  0.003867  0.003583  0.008501
# 5000    0.004518  0.001758  0.003271  0.003582  0.010980
# 15000   0.004513  0.001744  0.003187  0.003580  0.007054
# 25000   0.004500  0.001776  0.003334  0.003602  0.007468
# 100000  0.004723  0.001959  0.003234  0.003499  0.007722

# %%
#del_df.to_csv('./Results/del_size_change-3.csv')

# %% [markdown]
# ### Visualize Results

# %%
ax = insert_df.plot(figsize=(16,9), style='.-');
ax.set_xscale('log');
ax.set_title('Insert Keys - Hash Table Size Change');

# %%
ax = get_df.plot(figsize=(16,9), style='.-');
ax.set_xscale('log');
ax.set_title('Get Keys - Hash Table Size Change');

# %%
ax = del_df.plot(figsize=(16,9), style='.-');
ax.set_xscale('log');
ax.set_title('Delete Keys - Hash Table Size Change');

# %% [markdown]
# ## N. Keys Analsysis

# %% [markdown]
# ### Hash Tables

# %%
def get_results(kind, n_keys_insert, n_keys_get):
    res_insert = []
    res_get = []
    del_get = []
    for i in range(len(n_keys_insert)):
        print(kind, n_keys_insert[i], n_keys_get[i], n_keys_del[i])
        hashtable = get_hashtable(kind, size)
        insert = %timeit -o -n 100 insert_keys(hashtable, n=n_keys_insert[i])
        get = %timeit -o -n 100 get_values(hashtable, n=n_keys_get[i])
        delete = %timeit -o -n 100 delete_values(hashtable, n=n_keys_del[i])
        res_insert.append(insert)
        res_get.append(get)
        del_get.append(delete)
    return res_insert, res_get, del_get

# %%
size = 250
n_keys_insert = [10, 100, 250, 500, 1000, 2500, 5000, 10000, 50000]
n_keys_get = [10, 100, 250, 500, 1000, 2500, 5000, 10000, 50000]
n_keys_del = [10, 100, 250, 500, 1000, 2500, 5000, 10000, 50000]
hashtables = ['Naive', 'Default', 'MD5', 'SHA256', 'Jenkins']

# %%
results = []
for i, kind in enumerate(hashtables):
    results.append((kind, get_results(kind, n_keys_insert, n_keys_get)))
# Out:
# Naive 10 10
# 29 µs ± 6.98 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 25.4 µs ± 2.37 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 25.6 µs ± 3.84 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 100 100
# 223 µs ± 78.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 198 µs ± 3.07 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 203 µs ± 7.55 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 250 250
# 427 µs ± 18.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 541 µs ± 19.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 532 µs ± 7.38 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 500 500
# 887 µs ± 46.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.24 ms ± 69.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.26 ms ± 34.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 1000 1000
# 1.79 ms ± 34 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.37 ms ± 171 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.88 ms ± 346 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 2500 2500
# 5.28 ms ± 291 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.76 ms ± 271 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.88 ms ± 138 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 5000 5000
# 10.4 ms ± 194 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 31.2 ms ± 1.02 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 32.4 ms ± 520 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 10000 10000
# 21 ms ± 729 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 115 ms ± 2.27 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 124 ms ± 9.19 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive 50000 50000
# 124 ms ± 8.31 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.03 s ± 30 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.8 s ± 195 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 10 10
# 18.2 µs ± 8.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 13.6 µs ± 640 ns per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 13.4 µs ± 622 ns per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 100 100
# 121 µs ± 17.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 112 µs ± 2.37 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 115 µs ± 4.76 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 250 250
# 247 µs ± 20.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 290 µs ± 7.73 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 293 µs ± 6.04 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 500 500
# 516 µs ± 24 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 611 µs ± 9.75 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 617 µs ± 9.07 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 1000 1000
# 989 µs ± 34.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.35 ms ± 25.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.37 ms ± 17.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 2500 2500
# 2.37 ms ± 34 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.05 ms ± 36.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.14 ms ± 59.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 5000 5000
# 4.7 ms ± 48.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 10.4 ms ± 571 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 10.3 ms ± 120 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 10000 10000
# 9.52 ms ± 175 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 28.5 ms ± 254 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 29.4 ms ± 876 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Default 50000 50000
# 49 ms ± 633 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 557 ms ± 3.38 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 565 ms ± 5.91 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 10 10
# 34.3 µs ± 15.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 29.5 µs ± 2.92 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 26.4 µs ± 1.35 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 100 100
# 229 µs ± 15.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 256 µs ± 7.63 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 264 µs ± 2.81 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 250 250
# 566 µs ± 21.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 643 µs ± 6.61 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 669 µs ± 14.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 500 500
# 1.14 ms ± 34.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.34 ms ± 12.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.37 ms ± 12.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 1000 1000
# 2.3 ms ± 56.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.79 ms ± 52.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.86 ms ± 36.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 2500 2500
# 5.76 ms ± 20.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.32 ms ± 915 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.21 ms ± 144 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 5000 5000
# 12 ms ± 870 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 17.6 ms ± 236 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 18.2 ms ± 183 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 10000 10000
# 23.8 ms ± 1.46 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 43.8 ms ± 715 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 45.6 ms ± 1.32 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# MD5 50000 50000
# 118 ms ± 1.91 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 636 ms ± 1.53 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 639 ms ± 9.89 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 10 10
# 34.1 µs ± 11.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 34.4 µs ± 5.42 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 35.1 µs ± 6.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 100 100
# 248 µs ± 19.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 272 µs ± 4.97 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 278 µs ± 4.44 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 250 250
# 606 µs ± 19.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 698 µs ± 17.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 707 µs ± 11 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 500 500
# 1.21 ms ± 32.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.42 ms ± 12.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.46 ms ± 12.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 1000 1000
# 2.47 ms ± 51.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.94 ms ± 52.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.31 ms ± 370 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 2500 2500
# 6.13 ms ± 63.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.15 ms ± 136 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.56 ms ± 236 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 5000 5000
# 12.2 ms ± 63.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 18.4 ms ± 261 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 18.9 ms ± 83.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 10000 10000
# 24.7 ms ± 194 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 45 ms ± 378 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 46.9 ms ± 1.86 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# SHA256 50000 50000
# 125 ms ± 896 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 644 ms ± 6.1 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 827 ms ± 26.3 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 10 10
# 73.3 µs ± 29.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 58.9 µs ± 2.49 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 58.5 µs ± 2.91 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 100 100
# 597 µs ± 32.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 603 µs ± 7.43 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 601 µs ± 12.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 250 250
# 1.5 ms ± 40.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.57 ms ± 42.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.57 ms ± 32.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 500 500
# 3.03 ms ± 22.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.32 ms ± 102 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.82 ms ± 637 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 1000 1000
# 6.73 ms ± 401 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.81 ms ± 515 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.59 ms ± 562 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 2500 2500
# 16.6 ms ± 166 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 19.2 ms ± 876 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 18.8 ms ± 459 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 5000 5000
# 34.6 ms ± 2.16 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 40.9 ms ± 1.53 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 38.6 ms ± 621 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 10000 10000
# 66.6 ms ± 1.31 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 93.9 ms ± 3.78 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 94.8 ms ± 4.39 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Jenkins 50000 50000
# 359 ms ± 8.26 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.03 s ± 17.6 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 884 ms ± 48.4 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Red Black Tree

# %%
def get_results_rb_tree(n_keys_insert, n_keys_get):
    res_insert = []
    res_get = []
    res_del = []
    for i in range(len(n_keys_insert)):
        print(n_keys_insert[i], n_keys_get[i])
        insert = %timeit -o -n 100 insert_keys(num_rbt, n=n_keys_insert[i])
        get = %timeit -o -n 100 get_values(num_rbt, n=n_keys_get[i])
        delete = %timeit -o -n 100 delete_values(num_rbt, n=n_keys_del[i])
        res_insert.append(insert)
        res_get.append(get)
        res_del.append(delete)
    return res_insert, res_get, res_del

# %%
num_rbt = MapRBTree()
results = [('Red Black Tree', get_results_rb_tree(n_keys_insert, n_keys_get))]
# Out:
# 10 10
# 18.8 µs ± 617 ns per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 36.7 µs ± 4.49 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 25.2 µs ± 1.41 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 100 100
# 308 µs ± 35.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 579 µs ± 58.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 259 µs ± 34.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 250 250
# 866 µs ± 20.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.65 ms ± 38.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 747 µs ± 64.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 500 500
# 1.95 ms ± 40.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.64 ms ± 28.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.95 ms ± 122 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1000 1000
# 4.89 ms ± 602 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.81 ms ± 592 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.63 ms ± 90.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2500 2500
# 13.2 ms ± 815 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 23.5 ms ± 364 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 30.6 ms ± 1.46 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5000 5000
# 28.1 ms ± 580 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 54.6 ms ± 2.84 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 107 ms ± 734 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 10000 10000
# 57 ms ± 2.69 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 111 ms ± 1.66 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 435 ms ± 8.51 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 50000 50000
# 335 ms ± 3.27 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 638 ms ± 3.85 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-43-0d4027107daf> in <module>
#       1 num_rbt = MapRBTree()
# ----> 2 results = [('Red Black Tree', get_results_rb_tree(n_keys_insert, n_keys_get))]
#
# <ipython-input-40-94fa2eb53c07> in get_results_rb_tree(n_keys_insert, n_keys_get)
#       7         insert = get_ipython().run_line_magic('timeit', '-o -n 100 insert_keys(num_rbt, n=n_keys_insert[i])')
#       8         get = get_ipython().run_line_magic('timeit', '-o -n 100 get_values(num_rbt, n=n_keys_get[i])')
# ----> 9         delete = get_ipython().run_line_magic('timeit', '-o -n 100 delete_values(hashtable, n=n_keys_del[i])')
#      10         res_insert.append(insert)
#      11         res_get.append(get)
#
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# <decorator-gen-53> in timeit(self, line, cell, local_ns)
#
# /usr/local/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.9/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell, local_ns)
#    1171                     break
#    1172
# -> 1173         all_runs = timer.repeat(repeat, number)
#    1174         best = min(all_runs) / number
#    1175         worst = max(all_runs) / number
#
# /usr/local/Cellar/python@3.9/3.9.1_2/Frameworks/Python.framework/Versions/3.9/lib/python3.9/timeit.py in repeat(self, repeat, number)
#     203         r = []
#     204         for i in range(repeat):
# --> 205             t = self.timeit(number)
#     206             r.append(t)
#     207         return r
#
# /usr/local/lib/python3.9/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <ipython-input-3-5978e56d3726> in delete_values(hashtable, n)
#       9 def delete_values(hashtable, n=10000):
#      10     for i in range(n):
# ---> 11         hashtable.delete(str(i), testing=True)
#
# ~/git/dictionaries-implementation/HashTable.py in delete(self, key, testing)
#      61                         self.data[address].remove(current_list[i])
#      62                     return
# ---> 63             raise Exception("Key not found")
#      64         else:
#      65             raise Exception("Key not found")
#
# Exception: Key not found

# %% [markdown]
# ### Format Results

# %%
#insert
insert_res= []
for i in [res[1][0] for res in results]: 
    insert_res.append([statistics.mean(time_res.timings) for time_res in i])
    
insert_key_change_df = pd.DataFrame(insert_res).T
insert_key_change_df.columns=[res[0] for res in results]
insert_key_change_df.index = n_keys_insert

# %%
#insert
insert_res= []
for i in [res[1][0] for res in results]: 
    insert_res.append([statistics.mean(time_res.timings) for time_res in i])
    
insert_key_change_rb_df = pd.DataFrame(insert_res).T
insert_key_change_rb_df.columns=[res[0] for res in results]
insert_key_change_rb_df.index = n_keys_insert

# %%
insert_key_change_df = insert_key_change_df.join(insert_key_change_rb_df)

# %%
#insert_key_change_df.to_csv('./Results/insert_key_change_df-3.csv')

# %%
insert_key_change_df = pd.read_csv('./Results/insert_key_change_df.csv')
insert_key_change_df = insert_key_change_df[insert_key_change_df.columns[1:]]
insert_key_change_df.index = n_keys_insert

# %%
insert_key_change_df
# Out:
#           Naive   Default       MD5    SHA256   Jenkins  Red Black Tree
# 10     0.000020  0.000017  0.000033  0.000034  0.000069        0.000038
# 100    0.000190  0.000121  0.000236  0.000254  0.000572        0.000364
# 250    0.000470  0.000324  0.000591  0.000627  0.001437        0.001012
# 500    0.000887  0.000536  0.001188  0.001246  0.002897        0.002132
# 1000   0.001879  0.001019  0.002401  0.002489  0.005822        0.004641
# 2500   0.004521  0.002344  0.005917  0.006222  0.014848        0.012229
# 5000   0.009122  0.004618  0.011789  0.012314  0.029844        0.034278
# 10000  0.018440  0.009316  0.023679  0.024666  0.059776        0.064066
# 50000  0.102916  0.046893  0.122330  0.124382  0.304135        0.373617

# %%
#get
get_res = []
for i in [res[1][1] for res in results]: 
    get_res.append([statistics.mean(time_res.timings) for time_res in i])
    
get_key_change_df = pd.DataFrame(get_res).T
get_key_change_df.columns=[res[0] for res in results]
get_key_change_df.index = n_keys_get

# %%
#get
get_res = []
for i in [res[1][1] for res in results]: 
    get_res.append([statistics.mean(time_res.timings) for time_res in i])
    
get_key_change_rb_df = pd.DataFrame(get_res).T
get_key_change_rb_df.columns=[res[0] for res in results]
get_key_change_rb_df.index = n_keys_get

# %%
get_key_change_df = get_key_change_df.join(get_key_change_rb_df)

# %%
#get_key_change_df.to_csv('./Results/get_key_change_df-3.csv')

# %%
get_key_change_df = pd.read_csv('./Results/get_key_change_df-2.csv')
get_key_change_df = get_key_change_df[get_key_change_df.columns[1:]]
get_key_change_df.index = n_keys_get

# %%
get_key_change_df
# Out:
#           Naive   Default       MD5    SHA256   Jenkins
# 10     0.000025  0.000014  0.000029  0.000034  0.000059
# 100    0.000198  0.000112  0.000256  0.000272  0.000603
# 250    0.000541  0.000290  0.000643  0.000698  0.001575
# 500    0.001242  0.000611  0.001335  0.001415  0.003317
# 1000   0.003371  0.001351  0.002791  0.002942  0.007813
# 2500   0.009759  0.004054  0.008320  0.008152  0.019219
# 5000   0.031242  0.010411  0.017580  0.018415  0.040930
# 10000  0.114959  0.028455  0.043820  0.044982  0.093924
# 50000  2.025010  0.557206  0.635710  0.643698  1.026220

# %%
#del
del_res = []
for i in [res[1][2] for res in results]: 
    del_res.append([statistics.mean(time_res.timings) for time_res in i])
    
del_key_change_df = pd.DataFrame(del_res).T
del_key_change_df.columns=[res[0] for res in results]
del_key_change_df.index = n_keys_get

# %%
del_key_change_df
# Out:
#           Naive   Default       MD5    SHA256   Jenkins
# 10     0.000026  0.000013  0.000026  0.000035  0.000058
# 100    0.000203  0.000115  0.000264  0.000278  0.000601
# 250    0.000532  0.000293  0.000669  0.000707  0.001571
# 500    0.001263  0.000617  0.001369  0.001456  0.003815
# 1000   0.003879  0.001365  0.002857  0.003308  0.007593
# 2500   0.009881  0.004144  0.008206  0.008558  0.018794
# 5000   0.032371  0.010350  0.018154  0.018885  0.038649
# 10000  0.123771  0.029447  0.045558  0.046856  0.094819
# 50000  1.799949  0.564503  0.638707  0.827162  0.884025

# %%
#del_key_change_df.to_csv('./Results/del_key_change_df-3.csv')

# %% [markdown]
# ### Visualize Results

# %%
ax = insert_key_change_df.div(insert_key_change_df.index.to_series(), axis=0).plot(figsize=(16,9), style='.-');
ax.set_xscale('log');
ax.set_title('Insert Keys - Num Keys Change (size 250) - Seconds per Key Insert');

# %%
ax = get_key_change_df.div(get_key_change_df.index.to_series(), axis=0).plot(figsize=(16,9), style='.-');
ax.set_xscale('log');
ax.set_title('Get Keys - Num Keys Change (size 250) - Seconds per Key Get');

# %%
ax = del_key_change_df.div(del_key_change_df.index.to_series(), axis=0).plot(figsize=(16,9), style='.-');
ax.set_xscale('log');
ax.set_title('Delete Keys - Num Keys Change (size 250) - Seconds per Key Delete');

# %% [markdown]
# ### Log Comparison for Red Black Tree

# %%
from utils import plot_multi

# %%
temp_df = pd.DataFrame(np.log(insert_key_change_df.index))
temp_df['b'] = insert_key_change_df.div(insert_key_change_df.index.to_series(), axis=0)[['Red Black Tree']].values
temp_df['c'] = get_key_change_df.div(get_key_change_df.index.to_series(), axis=0)[['Red Black Tree']].values
temp_df.index = get_key_change_df.index
temp_df.columns = ['log(keys)', 'Red Black Tree (insert)', 'Red Black Tree (get)']

# %%
temp_df
# Out:
#        log(keys)  Red Black Tree (insert)  Red Black Tree (get)
# 10      2.302585                 0.000004              0.000004
# 100     4.605170                 0.000004              0.000006
# 250     5.521461                 0.000004              0.000007
# 500     6.214608                 0.000004              0.000007
# 1000    6.907755                 0.000005              0.000008
# 2500    7.824046                 0.000005              0.000012
# 5000    8.517193                 0.000007              0.000011
# 10000   9.210340                 0.000006              0.000012
# 50000  10.819778                 0.000007              0.000015

# %%
ax = plot_multi(temp_df, figsize=(16, 9), style='.-', title='Comparison log(keys) and Reed Black Tree');
ax.set_xscale('log');

# %% [markdown]
# # Improving Performance
#
# *Not working anymore, got previously executed on Hash Table with python dict instead of python list for hash collisions*

# %%
from NHashTable import DefaultNHashTable

# %%
def get_results_default_n(n_keys_insert, n_keys_get):
    res_insert = []
    res_get = []
    for i in range(len(n_keys_insert)):
        print(n_keys_insert[i], n_keys_get[i])
        insert = %timeit -o -n 100 insert_keys(default_nht, n=n_keys_insert[i])
        get = %timeit -o -n 100 get_values(default_nht, n=n_keys_get[i])
        res_insert.append(insert)
        res_get.append(get)
    return res_insert, res_get

# %%
def insert_keys(hashtable, n=10000):
    for i in range(n):
        hashtable.append(str(i), i)
        
def get_values(hashtable, n=10000):
    for i in range(n):
        hashtable.get(str(i))

# %%
default_nht = DefaultNHashTable(250)
n_keys_insert = [10, 100, 250, 500, 1000, 2500, 5000, 10000, 50000]
n_keys_get = [10, 100, 250, 500, 1000, 2500, 5000, 10000, 50000]

# %%
results = [('Default N', get_results_default_n(n_keys_insert, n_keys_get))]

# %%
#insert
insert_res= []
for i in [res[1][0] for res in results]: 
    insert_res.append([statistics.mean(time_res.timings) for time_res in i])
    
insert_key_change_def_n = pd.DataFrame(insert_res).T
insert_key_change_def_n.columns=[res[0] for res in results]
insert_key_change_def_n.index = n_keys_insert

insert_key_change_df = insert_key_change_df.join(insert_key_change_def_n)

# %%
insert_key_change_df
# Out:
#           Naive   Default       MD5    SHA256   Jenkins  Red Black Tree  \
# 10     0.000020  0.000017  0.000033  0.000034  0.000069        0.000038
# 100    0.000190  0.000121  0.000236  0.000254  0.000572        0.000364
# 250    0.000470  0.000324  0.000591  0.000627  0.001437        0.001012
# 500    0.000887  0.000536  0.001188  0.001246  0.002897        0.002132
# 1000   0.001879  0.001019  0.002401  0.002489  0.005822        0.004641
# 2500   0.004521  0.002344  0.005917  0.006222  0.014848        0.012229
# 5000   0.009122  0.004618  0.011789  0.012314  0.029844        0.034278
# 10000  0.018440  0.009316  0.023679  0.024666  0.059776        0.064066
# 50000  0.102916  0.046893  0.122330  0.124382  0.304135        0.373617
#
#        Default N
# 10      0.000011
# 100     0.000107
# 250     0.000208
# 500     0.000439
# 1000    0.000972
# 2500    0.002172
# 5000    0.004517
# 10000   0.009828
# 50000   0.048352

# %%
#get
get_res = []
for i in [res[1][1] for res in results]: 
    get_res.append([statistics.mean(time_res.timings) for time_res in i])
    
get_key_change_def_n = pd.DataFrame(get_res).T
get_key_change_def_n.columns=[res[0] for res in results]
get_key_change_def_n.index = n_keys_get

get_key_change_df = get_key_change_df.join(get_key_change_def_n)

# %%
get_key_change_df
# Out:
#           Naive   Default       MD5    SHA256   Jenkins  Red Black Tree  \
# 10     0.000025  0.000015  0.000032  0.000033  0.000058        0.000039
# 100    0.000234  0.000110  0.000273  0.000282  0.000586        0.000601
# 250    0.000521  0.000282  0.000677  0.000702  0.001511        0.001772
# 500    0.001239  0.000601  0.001370  0.001402  0.003031        0.003666
# 1000   0.003137  0.001317  0.002849  0.002933  0.006256        0.008068
# 2500   0.008270  0.003888  0.007886  0.007973  0.016457        0.030322
# 5000   0.025720  0.009741  0.017701  0.017976  0.034745        0.056033
# 10000  0.095544  0.026674  0.043108  0.043350  0.076871        0.117713
# 50000  1.403718  0.461325  0.569312  0.560277  0.728794        0.727403
#
#        Default N
# 10      0.000010
# 100     0.000087
# 250     0.000190
# 500     0.000414
# 1000    0.000804
# 2500    0.001972
# 5000    0.004483
# 10000   0.009037
# 50000   0.046993

# %%
columns = ['Default', 'Default N']

ax = insert_key_change_df.div(insert_key_change_df.index.to_series(), axis=0)[columns].plot(figsize=(16,9), style='.-');
ax.set_xscale('log');
ax.set_title('Insert Keys - Hash Table Num Keys Change (size 250) - Seconds per Key Insert');

# %%
ax = get_key_change_df.div(get_key_change_df.index.to_series(), axis=0)[columns].plot(figsize=(16,9), style='.-');
ax.set_xscale('log');
ax.set_title('Get Keys - Hash Table Num Keys Change (size 250) - Seconds per Key Get');
